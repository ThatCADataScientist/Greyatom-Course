# %% [markdown]
# <a href="https://colab.research.google.com/github/VarunNangalia/Greyatom-Course/blob/master/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-58b7e675-023a-4c3f-b046-e55cdf0c413c" name="files[]" multiple disabled />
#      <output id="result-58b7e675-023a-4c3f-b046-e55cdf0c413c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prize.json to prize.json
# ...

# %%
import json
with open('./prize.json') as g:
  data = json.load(g)
for x in data[1].items():
  print(x)
# Out:
# ('Year', 1901)
# ('Category', 'Literature')
# ('Prize', 'The Nobel Prize in Literature 1901')
# ('Motivation', '"in special recognition of his poetic composition, which gives evidence of lofty idealism, artistic perfection and a rare combination of the qualities of both heart and intellect"')
# ('Prize Share', '1/1')
# ('Laureate ID', 569)
# ('Laureate Type', 'Individual')
# ('Full Name', 'Sully Prudhomme')
# ('Birth Date', '1839-03-16')
# ('Birth City', 'Paris')
# ('Birth Country', 'France')
# ('Sex', 'Male')
# ('Organization Name', '')
# ('Organization City', '')
# ('Organization Country', '')
# ('Death Date', '1907-09-07')
# ('Death City', 'Châtenay')
# ('Death Country', 'France')

# %%
data
# Out:
# [{'Birth City': 'Rotterdam',
#   'Birth Country': 'Netherlands',
#   'Birth Date': '1852-08-30',
#   'Category': 'Chemistry',
#   'Death City': 'Berlin',
#   'Death Country': 'Germany',
#   'Death Date': '1911-03-01',
#   'Full Name': "Jacobus Henricus van 't Hoff",
#   'Laureate ID': 160,
#   'Laureate Type': 'Individual',
#   'Motivation': '"in recognition of the extraordinary services he has rendered by the discovery of the laws of chemical dynamics and osmotic pressure in solutions"',
#   'Organization City': 'Berlin',
#   'Organization Country': 'Germany',
#   'Organization Name': 'Berlin University',
#   'Prize': 'The Nobel Prize in Chemistry 1901',
#   'Prize Share': '1/1',
#   'Sex': 'Male',
#   'Year': 1901},
#  {'Birth City': 'Paris',
#   'Birth Country': 'France',
#   'Birth Date': '1839-03-16',
#   'Category': 'Literature',
#   'Death City': 'Châtenay',
#   'Death Country': 'France',
#   'Death Date': '1907-09-07',
#   'Full Name': 'Sully Prudhomme',
# ...

# %%
if data[0]["Sex"] == "Female":
  print(data[0])
else:
  print("WORD")
# Out:
# WORD

# %%
print(len(data))
# Out:
# 969

# %%
for i in data:
  print(i["Sex"])
# Out:
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
#
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
#
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
#
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# ...

# %%
count

# %%
male_count = 0
female_count = 0
No_sex = 0 
for i in range(0,len(data)):
  if (data[i]["Birth Country"] == "India" or data[i]["Death Country"] == "India") and data[i]["Sex"] == "Male" :
    male_count = male_count + 1
  elif (data[i]["Birth Country"] == "India" or data[i]["Death Country"] == "India") and data[i]["Sex"] == "Female" :
    female_count = female_count + 1
  else:
    No_sex = No_sex + 1

print('There are',male_count,'Indian males')
print('There are',female_count,'Indian females')
print('There are',No_sex,'blanks')
# Out:
# There are 7 Indian males
# There are 1 Indian females
# There are 961 blanks

# %%
countries_name = []
for i in range(0,len(data)):
  countries_name.append(data[i]['Birth Country'])
  countries_name.append(data[i]['Death Country'])
  
countries_name
# Out:
# ['Netherlands',
#  'Germany',
#  'France',
#  'France',
#  'Prussia (Poland)',
#  'Germany',
#  'Switzerland',
#  'Switzerland',
#  'France',
#  'France',
#  'Prussia (Germany)',
#  'Germany',
#  'Prussia (Germany)',
#  'Germany',
#  'Schleswig (Germany)',
#  'Germany',
#  'India',
#  'United Kingdom',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Switzerland',
#  'Netherlands',
#  'Netherlands',
#  'Netherlands',
#  'Netherlands',
#  'Sweden',
#  'Sweden',
#  'Norway',
#  'France',
#  'Faroe Islands (Denmark)',
#  'Denmark',
#  'United Kingdom',
#  'United Kingdom',
#  'France',
#  'France',
#  'France',
#  'France',
#  'Russian Empire (Poland)',
#  'France',
#  'Scotland',
#  'United Kingdom',
#  'France',
#  'France',
#  'Spain',
#  'Spain',
#  'Russia',
#  'Russia',
#  '',
#  '',
#  'United Kingdom',
#  'United Kingdom',
#  'Prussia (Germany)',
#  'Germany',
#  'Poland',
#  'Switzerland',
#  'Germany',
#  'Germany',
#  'Austrian Empire (Czech Republic)',
# ...

# %%
for i in range(0,len(data)):
  for j in range(0,5):
    print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
# 0 4
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4
# 2 0
# 2 1
# 2 2
# 2 3
# 2 4
# 3 0
# 3 1
# 3 2
# 3 3
# 3 4
# 4 0
# 4 1
# 4 2
# 4 3
# 4 4
# 5 0
# 5 1
# 5 2
# 5 3
# 5 4
# 6 0
# 6 1
# 6 2
# 6 3
# 6 4
# 7 0
# 7 1
# 7 2
# 7 3
# 7 4
# 8 0
# 8 1
# 8 2
# 8 3
# 8 4
# 9 0
# 9 1
# 9 2
# 9 3
# 9 4
# 10 0
# 10 1
# 10 2
# 10 3
# 10 4
# 11 0
# 11 1
# 11 2
# 11 3
# 11 4
# 12 0
# 12 1
# 12 2
# 12 3
# 12 4
# 13 0
# 13 1
# 13 2
# 13 3
# 13 4
# 14 0
# 14 1
# 14 2
# 14 3
# 14 4
# 15 0
# 15 1
# 15 2
# 15 3
# 15 4
# 16 0
# 16 1
# 16 2
# 16 3
# 16 4
# 17 0
# 17 1
# 17 2
# 17 3
# 17 4
# 18 0
# 18 1
# 18 2
# 18 3
# 18 4
# 19 0
# 19 1
# 19 2
# 19 3
# 19 4
# 20 0
# 20 1
# 20 2
# 20 3
# 20 4
# 21 0
# 21 1
# 21 2
# 21 3
# 21 4
# 22 0
# 22 1
# 22 2
# 22 3
# 22 4
# 23 0
# 23 1
# 23 2
# 23 3
# 23 4
# 24 0
# 24 1
# 24 2
# 24 3
# 24 4
# 25 0
# 25 1
# 25 2
# 25 3
# 25 4
# 26 0
# 26 1
# 26 2
# 26 3
# 26 4
# 27 0
# 27 1
# 27 2
# 27 3
# 27 4
# 28 0
# 28 1
# 28 2
# 28 3
# 28 4
# 29 0
# 29 1
# 29 2
# 29 3
# 29 4
# ...

# %%
nobel_category = ['Medicine','Literature','Physics','Economics','Chemistry','Peace']
category = {}
for i in nobel_category:
  cat_len = 0
  for j in range(len(data)):
    if((data[j]['Birth Country'] == 'India') or (data[j]['Death Country'] == 'India') or(data[j]['Birth Country'] == 'British India (India)') or(data[j]['Organization Country'] == 'India')) and (data[j]['Category']== i):
      cat_len = cat_len + 1
    category[i] = cat_len
print(category)
# Out:
# {'Medicine': 2, 'Literature': 2, 'Physics': 1, 'Economics': 1, 'Chemistry': 1, 'Peace': 2}

# %%
num1 = 0
condtion = None
if num1 < 0:
  print("Negative")
elif num1 > 0:
  print("Possitive")
else:
  print("Zero")
# Out:
# Zero

# %%
var = []
for i in range(1,61):
  if i % 2 == 0 or i % 3 == 0:
    var.append(i)
print(var)
# Out:
# [2, 3, 4, 6, 8, 9, 10, 12, 14, 15, 16, 18, 20, 21, 22, 24, 26, 27, 28, 30, 32, 33, 34, 36, 38, 39, 40, 42, 44, 45, 46, 48, 50, 51, 52, 54, 56, 57, 58, 60]

# %%
for i in range(1,11):
  print(i**2,end=" ")
# Out:
# 1 4 9 16 25 36 49 64 81 100

# %%
data
# Out:
# [{'Birth City': 'Rotterdam',
#   'Birth Country': 'Netherlands',
#   'Birth Date': '1852-08-30',
#   'Category': 'Chemistry',
#   'Death City': 'Berlin',
#   'Death Country': 'Germany',
#   'Death Date': '1911-03-01',
#   'Full Name': "Jacobus Henricus van 't Hoff",
#   'Laureate ID': 160,
#   'Laureate Type': 'Individual',
#   'Motivation': '"in recognition of the extraordinary services he has rendered by the discovery of the laws of chemical dynamics and osmotic pressure in solutions"',
#   'Organization City': 'Berlin',
#   'Organization Country': 'Germany',
#   'Organization Name': 'Berlin University',
#   'Prize': 'The Nobel Prize in Chemistry 1901',
#   'Prize Share': '1/1',
#   'Sex': 'Male',
#   'Year': 1901},
#  {'Birth City': 'Paris',
#   'Birth Country': 'France',
#   'Birth Date': '1839-03-16',
#   'Category': 'Literature',
#   'Death City': 'Châtenay',
#   'Death Country': 'France',
#   'Death Date': '1907-09-07',
#   'Full Name': 'Sully Prudhomme',
# ...

# %%
a = 6
while a:
  print("a = ",a)
  a = a - 2
# Out:
# a =  6
# a =  4
# a =  2

# %%
[{str(i): i} for i in range(1,11) if i%2 == 0]
# Out:
# [{'2': 2}, {'4': 4}, {'6': 6}, {'8': 8}, {'10': 10}]

# %%
list_name = ["aa","bb","cc","dd","ee"]
list_name2 = [i+" "+"Hello" for i in list_name]
list_name2
# Out:
# ['aa Hello', 'bb Hello', 'cc Hello', 'dd Hello', 'ee Hello']

# %%
list_one=[1,2,3,4,5]
list_two=[6,7,8,9,10]
list_three=[list_one[i]+list_two[i] for i in range(len(list_one))]
list_three
# Out:
# [7, 9, 11, 13, 15]

# %%
list_four = [list_one[i] + list_two[j] for j in range(len(list_two)) for i in range(len(list_one))]
list_four
# Out:
# [7,
#  8,
#  9,
#  10,
#  11,
#  8,
#  9,
#  10,
#  11,
#  12,
#  9,
#  10,
#  11,
#  12,
#  13,
#  10,
#  11,
#  12,
#  13,
#  14,
#  11,
#  12,
#  13,
#  14,
#  15]

# %%
l_one = [1,2,3,4,5]
l_two = [3,5,7,9,11]
final = [i for i in l_one if i not in l_two]
final
# Out:
# [1, 2, 4]

# %%
p = [i  for i in range(1,11) if i%2 == 0]
p
# Out:
# [2, 4, 6, 8, 10]

# %%
print('functions')
# Out:
# functions

# %%
def square(a):
  return(a**2)
wh= square(55)
print(wh + wh)
# Out:
# 6050

# %%
def square(a,b):
  print(a**b)
  return(a**b)
square(2,4)
# Out:
# 16
# 16

# %%
def square(a,b):
  return(a**b)
  print(a**b)
print(square(2,5))
# Out:
# 32

# %%
def square(a=2,b=3):
  return(a**b)

square()
# Out:
# 8

# %%
def square(a=2,b=3):
  return(a**b)

square(5,3)
# Out:
# 125

# %%
def name(n="Varun"):
  print("Hello"+n)
name('and')
# Out:
# Helloand

# %%
def name(n="Hello varun",m="Greyatom"):
  print(n,m)
name()
name('Hello Wolrd',)
name('Hello Wolrd','Study')
name(m='Study')
# Out:
# Hello varun Greyatom
# Hello Wolrd Greyatom
# Hello Wolrd Study
# Hello varun Study

# %%
try :
  x = 1/0
except:
  print("there was an error")
# Out:
# there was an error

# %%
try :
  print(xyz)
except NameError:
  print("H")
# Out:
# H

# %%
try :
  print(xyz)
except NameError:
  print("H")
else :
  print("im")
finally :
  print("98765")
# Out:
# H
# 98765

# %%
try :
  print(1)
except NameError:
  print("This is printed when there is an error")
else :
  print("else is printed when there is No Error")
finally :
  print("This is printed irrespective of the error")
# Out:
# 1
# else is printed when there is No Error
# This is printed irrespective of the error

# %%
try:
  x = 1/0
except:
  pass
finally :
  print("pass is used when we have to ignore the errors totally and dont want to know the error at all")
# Out:
# pass is used when we have to ignore the errors totally and dont want to know the error at all

# %%
try:
  x = 1/0
except AssertionError as E:
  print(E)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-244-0120f0009b8b> in <module>()
#       1 try:
# ----> 2   x = 1/0
#       3 except AssertionError as E:
#       4   print(E)
#
# ZeroDivisionError: division by zero

# %%
try:
  print(xyzkjbhs)
except Exception as E:
  print(E)
# Out:
# name 'xyzkjbhs' is not defined

# %%
try :
  x = 1/0
except:
print("H")
# Out:
#   File "<ipython-input-249-111a373b00d4>", line 4
#     print("H")
#         ^
# IndentationError: expected an indented block

# %%
try :
  x = 1/0
except:
  pass
print("H")
# Out:
# H

# %%
with open('myfile.txt','w') as f:
  f.write("this is my first file\n")
  f.write("second line\n")
  f.write("this was done to write a text in files & ")

# %%
# !ls
# Out:
# myfile.txt  prize.json	sample_data

# %%
# !cat myfile.txt
# Out:
# this is my first file
# second line
# this was done to write a text in files
